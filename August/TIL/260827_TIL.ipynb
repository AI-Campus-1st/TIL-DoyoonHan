# %% [markdown]
# # 260827 Today I Learnt

# %% [markdown]
# ## API
#
# * 기관이 데이터를 주기로 하고 만든 공식 창구
#
# * 문서 읽는 순서
#
#     1. 엔드포인트
#
#     2. 요청 변수
#
#     3. 출력 결과
#
#     4. 에러 코드
#
# * 키 관리는 .env에
#
# * 서비스키 인코딩 함정
#     - SERVICE KEY IS NOT REGISTERED ERROR 나올 때 의심

# %% [markdown]
# ## 배치
#
# * 한 건씩 넣는것보다 수십 배 빠름.
#
# * 보통 500 ~ 1000건
