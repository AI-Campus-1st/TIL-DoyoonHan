# %% [markdown]
# # 260806 Today I Learnt

# %% [markdown]
# ## Pandas
#
# 데이터프레임과 시리즈라는 자료형

# %% [markdown]
# ### Series
#
# 1차원 array

# %% [markdown]
# * index -> series.index
#
# * value -> series.values
#
# * dictionary를 사용하면 key가 index가 됨.
#
# * Multi Index도 가능
#
# * np.nan

# %% [markdown]
# #### concat
#
# * 데이터 연결

# %% [markdown]
# ### DataFrame
#
# * 파일 읽기 -> pd.read_csv(filename, index_col, header, sep, encoding)
#
# * 파일 쓰기 -> df.to_csv(filename, encoding)
#
# * col 추가 -> df["colname"]
#
#  - apply 사용해서 function 사용가능.
#
#  - np.where(condtion, when True, when False)
#
# * row 추가 -> df.loc[n] = [row detail]
#
#  - loc: 명시한 index로 접근
#  - iloc: 묵시적 index(순서)로 접근
#
# * col 삭제
#  - del df[col]
#  - df.drop([col], axis = 1, inplace = True) -> inplace True하면 원본에 적용
#
# * df.groupby(one or list of col names)
#  - sum()
#  - head()
#  - mean() 등 붙여야 사용가능.
#
# * df.sort_values(by = "colname")
