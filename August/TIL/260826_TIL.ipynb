# %% [markdown]
# # 260826 Today I Learnt

# %% [markdown]
# ## 스레드 (from multiprocessing.dummy import Pool)
#
# 1. 메모리 -> 공유한다
#
# 2. 데이터 전달 -> 그냥 참조
#
# 3. 생성 비용 -> 작다
#
# 4. GIL -> 걸린다 (I/O중엔 해제)
#
# 5. 적합 -> 네트워크 대기
#
# ## 프로세스 (from multiprocessing import Pool)
#
# 1. 메모리 -> 따로 쓴다
#
# 2. 데이터 전달 -> 직렬화해서 복사
#
# 3. 생성 비용 -> 크다
#
# 4. GIL -> 각자 자기 GIL
#
# 5. 적합 -> 계산

# %% [markdown]
# ## 비동기 httpx
#
# * 스레드를 늘리는 대신, 기다리는 동안 다른 일을 함.
#
# * 기다림이 생길 때마다 다음 작업으로 넘어감
#
# * 전환 비용이 거의 없어 수천 개의 요청오 감당 가능
#
# * async/await 문법을 사용해야함

# %% [markdown]
# ## Scrapy
#
# * 좋은 도구이지만 언제나 정답은 아님
#
# 1. 수집 대상이 많고 오래 운영할 프로젝트 라면 Scrapy가 유리
#
# 2. 한두 사이트를 한 번 훑는 일이라면 직접 짜는 편이 빠름
#
# 3. 자바스크립트 렌더링이 플요하면 별도 플러그인이 필요
