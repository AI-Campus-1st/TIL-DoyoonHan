# %% [markdown]
# # 260820 Today I Learnt

# %% [markdown]
# ## 동적웹
#
# * requests로 받은 문자열에 브라우저에 나와있는 정보가 안나올 때 동적웹 의심.
#
# * JS로 API서버에서 따로 값을 가져옴.
#
# * Networks 탭에 Fetch/XHR 필터로 JS가 보낸 데이터 요청만 남김.
#
# * preview로 데이터 찾기
#
# * response.json() 으로 데이터 불러오기
