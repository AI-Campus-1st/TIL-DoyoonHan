# %% [markdown]
# # 260729 Today I Learnt

# %% [markdown]
# ## Global
#
# global keyword를 사용하면 function안에 있는 variable에 접근할 수 있으나 사용하는것은 비추.

# %% [markdown]
# ## Object-Oriented Programming (OOP)
#
# * type -> 어떤 operator와 method이 가능한가
#
# * attribute -> 어떤 데이터를 가지는가
#
# * method -> 어떤 함수를 할 수 있는가
