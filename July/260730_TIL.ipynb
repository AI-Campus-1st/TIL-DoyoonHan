# %% [markdown]
# # 260730 Today I Learnt

# %% [markdown]
# ## Class
#
# ### Magic Methods
#
#  * __str__(self)
#
#  * __len__(self)
#
#  * __repr__(self)
#
#  * __lt__(self, other)
#
#  * __le__(self, other)
#
#  * __eq__(self, other)
#
#  * __ne__(self, other)
#
#  * __gt__(self, other)
#
#  * __ge__(self, other)
#
# ### Class Methods
#
# * @classmethod -> 첫번째 인자로 cls가 전달됨
#
# ### Static Methods
#
# * @staticmethod -> 아무 인자도 전달되지 않음.

# %% [markdown]
# ## OOP
#
# * Inheritance
#
# super() -> 부모 클래스에서 가져옴 super().\_\_init\_\_(args of parent class)
#
# * Method Overriding
#
# 부모 클래스가 가지고있는 method를 덮음
#
# * Multiple Inheritance
#
# issubclass(class, classinfo)
#
# isinstnace(object, classinfo)

# %% [markdown]
# ## Module
#
# import하는 모듈들은 전부 py 파일들임. 만들어서 사용가능.
#
# ```py
# import module
# from module import var, function, Class
# from module import *
# ```
#
# ### 패키지
# ```py
# from package import module
# from package.module import var, function, Class
#
# ```
