# %% [markdown]
# # 260722 Today I Learnt

# %% [markdown]
# ## Identifiers
#
# 1. Boolean - True False
#
# 2. None
#
# 3. 논리연산자 - and or not
#
# 4. 비교연산 is
#
# 5. 포함 테스트 in
#
# 6. 변수 삭제 - del
#
# 7. 함수 - def / return
#
# 8. 클래스 정의 - class
#
# 9. 조건문 - if elif else / match case
#
# 10. 반복문 - for while / break continue pass
#
# 11. 모듈 - import from as
#
# 12. 에러처리 - try-except finally raise
