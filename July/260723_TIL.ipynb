# %% [markdown]
# # 260723 Today I Learnt

# %% [markdown]
# ## 군집형 data type

# %% [markdown]
# ### String
#
# 1. ''안에 '' 할때 \ 사용 권장
#
# 2. 여러 줄 할 때는 """content""" 사용
#
# <u>이스케이프 시퀀스</u>
#
# 1. \n - new line
# 2. \t - tab
# 3. \r - carriage return
# 4. \0 - Null
# 5. \\\ - \
#
# String is *Immutable* & *Ordered* & *Iterable*.
#
# <u>쓰는 함수</u>
#
# replace strip lstirp rstrip split join capitalize upper swapcase lower title
#
# |operation|설명|
# |---------|---|
# |x `in` s	|containment test|
# |x `not in` s|containment test|
# |s1 `+` s2|concatenation|
# |s `*` n|n번만큼 반복하여 더하기
# |`s[i]`|indexing|
# |`s[i:j]`|slicing|
# |`s[i:j:k`]|k간격으로 slicing|
# |len(s)|길이|
# |min(s)|최솟값|
# |max(s)|최댓값|
# |s.count(x)|x의 개수|

# %% [markdown]
# ### Container
#
# #### 특징
#
# 1. 순서를 가질 수 있다.
# 2. 특정 위치으 데이터를 가리킬 수 있다.
#
# #### 종류
#
# 1. List
# 2. Tuple
# 3. Range
# 4. String
# 5. Binary

# %% [markdown]
# ### List
#
# [1, 2, 3]
#
# make with [] or list()
#
#
# <u>쓰는 함수</u>
#
# .append() .extend() .insert(i, x) .remove() .pop() .clear() list.index .count() list.sort sorted() .reverse() list(reversed())

# %% [markdown]
# ### Tuple
#
# (1, 2, 3)
#
# Immutable

# %% [markdown]
# ### Range
#
# 기본: range(n)
#
# 범위: range(n, m)
#
# 범위 + 스텝: range(n, m, s)
