# %% [markdown]
# # 260727 Today I Learnt

# %% [markdown]
# ### 조건 표현식 Conditional Expression
#
# ```python
# true_value if <조건식> else false_value
# ```

# %% [markdown]
# ### List Comprehension
#
# result = [" ".join(name) for name in full_name]
#
# 보통의 for loop 보다 빠르다.

# %% [markdown]
# ### Enumerate()
#
# Provides index to iterable object
#
# list = [a, b, c]
#
# enumerate(list) -> [(0,a), (1,b), (2,c)]

# %% [markdown]
# ### For-else
#
# for:
#
# 1.
#
# else:
#
# 2.
#
# for loop 을 전부 실행한후 else를 실행. else를 막으려면 break 사용.
